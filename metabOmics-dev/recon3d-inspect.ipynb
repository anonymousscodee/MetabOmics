# %% [markdown]
# # Recon3D Model Inspect

# %%
import os

from cobra import Model, Reaction, Metabolite
from cobra.io import load_json_model, load_matlab_model

recon3d_path = os.path.join("datasets", "network_models", "Recon3D.json")  # JSON model
recon301_path = os.path.join("datasets", "network_models", "Recon3DModel_301.mat") # Matlab Model

# %%
recon3d = load_json_model(recon3d_path)
recon3d
# Out:
# <Model Recon3D at 0x23729adee80>

# %%
recon3d.metabolites[0]
# Out:
# <Metabolite 10fthf_c at 0x2370efabb80>

# %%
recon3d.reactions[0]
# Out:
# <Reaction 24_25DHVITD3tm at 0x2372cbfe0a0>

# %%
recon3d.reactions
# Out:
# [<Reaction 24_25DHVITD3tm at 0x2372cbfe0a0>,
#  <Reaction 25HVITD3t at 0x2372cbfe100>,
#  <Reaction COAtl at 0x2372cbfe130>,
#  <Reaction EX_5adtststerone_e at 0x2372cbfe160>,
#  <Reaction EX_5adtststerones_e at 0x2372cbfe2e0>,
#  <Reaction EX_5fthf_e at 0x2372cbfe550>,
#  <Reaction EX_5htrp_e at 0x2372cbfe640>,
#  <Reaction EX_5mthf_e at 0x2372cbfe700>,
#  <Reaction EX_5thf_e at 0x2372cbfe790>,
#  <Reaction EX_6dhf_e at 0x2372cbfe880>,
#  <Reaction 24_25VITD3Hm at 0x2372cbfe910>,
#  <Reaction 24NPHte at 0x2372cbfe0d0>,
#  <Reaction 10FTHF7GLUtl at 0x2372cbfea00>,
#  <Reaction 10FTHFtm at 0x2372cbfeeb0>,
#  <Reaction 11DOCRTSLtr at 0x2372cbfee80>,
#  <Reaction 13DAMPPOX at 0x2372cbfeac0>,
#  <Reaction 24_25DHVITD2t at 0x2372cc1b0a0>,
#  <Reaction 24_25DHVITD2tm at 0x2372cc1b1f0>,
#  <Reaction 24_25DHVITD3t at 0x2372cc1b490>,
#  <Reaction 25VITD2Hm at 0x2372cc1b7c0>,
#  <Reaction 2AMACHYD at 0x2372cc1b310>,
#  <Reaction 2AMACSULT at 0x2372cc1bcd0>,
# ...

# %%
recon301 = load_matlab_model(recon301_path)
recon301
# Out:
# <Model Recon3DModel at 0x2370e424f70>

# %%
recon301.reactions[0]
# Out:
# <Reaction 10FTHF5GLUtl at 0x2373c3c0a00>
